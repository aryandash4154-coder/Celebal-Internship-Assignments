# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\91993\Downloads\archive (8)\Sample - Superstore.csv", encoding="latin1")

# %%
df.head
# Out:
# <bound method NDFrame.head of       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.tail()
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  1/21/2014  1/23/2014    Second Class
# 9990    9991  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9991    9992  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9992    9993  CA-2017-121258  2/26/2017   3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017   5/9/2017    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID             str
# Order Date           str
# Ship Date            str
# Ship Mode            str
# Customer ID          str
# Customer Name        str
# Segment              str
# Country              str
# City                 str
# State                str
# Postal Code        int64
# Region               str
# Product ID           str
# Category             str
# Sub-Category         str
# Product Name         str
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# No missing values were found in the dataset, so no missing value handling was required.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
technology = df[df["Category"] == "Technology"]
technology.head()
# Out:
#     Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 7        8  CA-2014-115812   6/9/2014   6/14/2014  Standard Class    BH-11710
# 11      12  CA-2014-115812   6/9/2014   6/14/2014  Standard Class    BH-11710
# 19      20  CA-2014-143336  8/27/2014    9/1/2014    Second Class    ZD-21925
# 26      27  CA-2016-121755  1/16/2016   1/20/2016    Second Class    EH-13945
# 35      36  CA-2016-117590  12/8/2016  12/10/2016     First Class    GH-14485
#
#          Customer Name    Segment        Country           City  ...  \
# 7      Brosina Hoffman   Consumer  United States    Los Angeles  ...
# 11     Brosina Hoffman   Consumer  United States    Los Angeles  ...
# 19  Zuschuss Donatelli   Consumer  United States  San Francisco  ...
# 26       Eric Hoffmann   Consumer  United States    Los Angeles  ...
# 35           Gene Hale  Corporate  United States     Richardson  ...
#
#    Postal Code   Region       Product ID    Category Sub-Category  \
# ...

# %%
df[["Customer Name", "Category", "Sales", "Quantity"]].head()
# Out:
#      Customer Name         Category     Sales  Quantity
# 0      Claire Gute        Furniture  261.9600         2
# 1      Claire Gute        Furniture  731.9400         3
# 2  Darrin Van Huff  Office Supplies   14.6200         2
# 3   Sean O'Donnell        Furniture  957.5775         5
# 4   Sean O'Donnell  Office Supplies   22.3680         2

# %%
df["Price"] = df["Sales"] / df["Quantity"]

# %%
df["Total_Amount"] = df["Price"] * df["Quantity"]

# %%
df[["Sales", "Quantity", "Price", "Total_Amount"]].head()
# Out:
#       Sales  Quantity     Price  Total_Amount
# 0  261.9600         2  130.9800      261.9600
# 1  731.9400         3  243.9800      731.9400
# 2   14.6200         2    7.3100       14.6200
# 3  957.5775         5  191.5155      957.5775
# 4   22.3680         2   11.1840       22.3680

# %%
df.to_csv("cleaned_superstore.csv", index=False)

# %%
import os

os.listdir()
# Out:
# ['.3T',
#  '.bash_history',
#  '.cache',
#  '.codex',
#  '.copilot',
#  '.eclipse',
#  '.ghcp-appmod',
#  '.ghcp-appmod-java',
#  '.gitconfig',
#  '.gradle',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jdks',
#  '.jupyter',
#  '.m2',
#  '.matplotlib',
#  '.npmrc',
#  '.p2',
#  '.packettracer',
#  '.redhat',
#  '.swt',
#  '.vscode',
#  '.vscode-shared',
#  '11.java',
#  '15.java',
#  '2341004154',
#  '3D Objects',
#  'after operator',
#  'AppData',
#  'Application Data',
#  'Array',
#  'Assignment_1_data clean.ipynb',
#  'bigelement',
#  'bike.html',
#  'Cisco Packet Tracer 9.0.0',
#  'cleaned_dataset.csv',
#  'cleaned_superstore.csv',
#  'Contacts',
#  'Cookies',
#  'Documents',
#  'Downloads',
#  'drop.html',
#  'eclipse',
#  'EXAM',
#  'Favorites',
#  'form.html',
#  'IdeaProjects',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'navbar.html',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
# ...

# %% [markdown]
# Week 7 Assignment Summary
# Loaded the Superstore CSV dataset into a Pandas DataFrame.
# Explored the dataset using head(), tail(), shape, columns, dtypes, and info().
# Checked for missing values using isnull().sum() and found no missing values.
# Checked for duplicate rows and found no duplicates.
# Filtered the dataset for the Technology category.
# Selected important columns for analysis.
# Created the Price and Total_Amount derived columns.
# Saved the cleaned dataset as cleaned_superstore.csv.

# %%
import os
os.listdir()
# Out:
# ['.3T',
#  '.bash_history',
#  '.cache',
#  '.codex',
#  '.copilot',
#  '.eclipse',
#  '.ghcp-appmod',
#  '.ghcp-appmod-java',
#  '.gitconfig',
#  '.gradle',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jdks',
#  '.jupyter',
#  '.m2',
#  '.matplotlib',
#  '.npmrc',
#  '.p2',
#  '.packettracer',
#  '.redhat',
#  '.swt',
#  '.vscode',
#  '.vscode-shared',
#  '11.java',
#  '15.java',
#  '2341004154',
#  '3D Objects',
#  'after operator',
#  'AppData',
#  'Application Data',
#  'Array',
#  'Assignment_1_data clean.ipynb',
#  'bigelement',
#  'bike.html',
#  'Cisco Packet Tracer 9.0.0',
#  'cleaned_dataset.csv',
#  'cleaned_superstore.csv',
#  'Contacts',
#  'Cookies',
#  'Documents',
#  'Downloads',
#  'drop.html',
#  'eclipse',
#  'EXAM',
#  'Favorites',
#  'form.html',
#  'IdeaProjects',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'navbar.html',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
# ...
